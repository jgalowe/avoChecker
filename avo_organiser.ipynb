# %% [markdown]
# ### Workflow to classify new avocadoes
# Step 1: Rename the pictures in the folder

# %%
import os
from ultralytics import YOLO
model_yolo = YOLO("avoID.pt")

# %%
#establishing the folder name which we will use later in our renaming process
directory = 'Pictures/1023A'
folder_name = os.path.basename(directory)

index = 0
for item in os.listdir(directory):
    os.rename((directory + '/' + item), 
              (directory + '/' + folder_name + f'_{index}.jpg')), 
              
    index=index+1

# %% [markdown]
# Step 2: generate the crops for the avocados

# %%
model_yolo.predict(
        source=directory,
        save_crop=True,
        save=True,
        conf=0.5
    )
# Out:
# image 1/7 c:\Users\johnl\Documents\GitHub\avoChecker\Pictures\1023A\1023A_0.jpg: 640x512 1 Hass, 105.4ms
# image 2/7 c:\Users\johnl\Documents\GitHub\avoChecker\Pictures\1023A\1023A_1.jpg: 640x512 1 Hass, 108.2ms
# image 3/7 c:\Users\johnl\Documents\GitHub\avoChecker\Pictures\1023A\1023A_2.jpg: 640x512 1 Hass, 9.8ms
# image 4/7 c:\Users\johnl\Documents\GitHub\avoChecker\Pictures\1023A\1023A_3.jpg: 640x512 1 Hass, 9.7ms
# image 5/7 c:\Users\johnl\Documents\GitHub\avoChecker\Pictures\1023A\1023A_4.jpg: 640x512 1 Hass, 9.7ms
# image 6/7 c:\Users\johnl\Documents\GitHub\avoChecker\Pictures\1023A\1023A_5.jpg: 640x512 1 Hass, 9.5ms
# image 7/7 c:\Users\johnl\Documents\GitHub\avoChecker\Pictures\1023A\1023A_6.jpg: 640x512 1 Hass, 10.3ms
# Speed: 2.6ms preprocess, 37.5ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 512)
# Results saved to runs\detect\predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hass', 1: 'Shepard'}
#  obb: None
#  orig_img: array([[[ 52, 160, 255],
#          [ 51, 159, 255],
#          [ 48, 157, 255],
#          ...,
#          [162, 167, 168],
#          [161, 166, 167],
#          [161, 166, 167]],
#
#         [[ 51, 159, 255],
#          [ 49, 157, 255],
#          [ 47, 156, 254],
#          ...,
#          [163, 168, 169],
#          [162, 167, 168],
#          [162, 167, 168]],
#
#         [[ 48, 156, 255],
#          [ 47, 155, 255],
#          [ 45, 154, 252],
#          ...,
#          [165, 170, 171],
#          [165, 170, 171],
#          [164, 169, 170]],
#
#         ...,
#
#         [[194, 189, 188],
#          [185, 180, 179],
#          [179, 175, 174],
#          ...,
#          [196, 192, 191],
#          [195, 191, 190],
#          [194, 190, 189]],
#
#         [[196, 191, 190],
#          [183, 178, 177],
#          [174, 170, 169],
#          ...,
#          [181, 177, 176],
#          [181, 177, 176],
#          [181, 177, 176]],
#
#         [[193, 188, 187],
#          [174, 169, 168],
#          [157, 153, 152],
#          ...,
#          [175, 171, 170],
#          [176, 172, 171],
#          [176, 172, 171]]], dtype=uint8)
#  orig_shape: (1600, 1204)
#  path: 'c:\\Users\\johnl\\Documents\\GitHub\\avoChecker\\Pictures\\1023A\\1023A_0.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 4.122599959373474, 'inference': 105.38460011593997, 'postprocess': 1.4843998942524195},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hass', 1: 'Shepard'}
#  obb: None
#  orig_img: array([[[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [119, 130, 138],
#          [118, 129, 137],
#          [116, 127, 135]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [119, 130, 138],
#          [118, 129, 137],
#          [116, 127, 135]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [119, 130, 138],
#          [118, 129, 137],
#          [116, 127, 135]],
#
#         ...,
#
#         [[157, 156, 160],
#          [152, 151, 155],
#          [154, 150, 155],
#          ...,
#          [150, 148, 148],
#          [143, 141, 141],
#          [135, 133, 133]],
#
#         [[158, 157, 161],
#          [154, 153, 157],
#          [156, 152, 157],
#          ...,
#          [146, 144, 144],
#          [139, 137, 137],
#          [133, 131, 131]],
#
#         [[159, 158, 162],
#          [156, 155, 159],
#          [157, 153, 158],
#          ...,
#          [143, 141, 141],
#          [137, 135, 135],
#          [131, 129, 129]]], dtype=uint8)
#  orig_shape: (1600, 1204)
#  path: 'c:\\Users\\johnl\\Documents\\GitHub\\avoChecker\\Pictures\\1023A\\1023A_1.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 3.729600226506591, 'inference': 108.15509990788996, 'postprocess': 1.7093999776989222},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hass', 1: 'Shepard'}
#  obb: None
#  orig_img: array([[[  4, 156, 251],
#          [  4, 156, 251],
#          [  4, 156, 251],
#          ...,
#          [153, 156, 154],
#          [153, 156, 154],
#          [152, 155, 153]],
#
#         [[  4, 156, 251],
#          [  4, 156, 251],
#          [  4, 156, 251],
#          ...,
#          [153, 156, 154],
#          [153, 156, 154],
#          [152, 155, 153]],
#
#         [[  4, 153, 251],
#          [  4, 153, 251],
#          [  4, 153, 251],
#          ...,
#          [153, 156, 154],
#          [153, 156, 154],
#          [153, 156, 154]],
#
#         ...,
#
#         [[172, 170, 170],
#          [173, 171, 171],
#          [174, 172, 172],
#          ...,
#          [134, 135, 133],
#          [139, 140, 138],
#          [142, 143, 141]],
#
#         [[174, 172, 172],
#          [176, 174, 174],
#          [177, 175, 175],
#          ...,
#          [129, 130, 128],
#          [136, 137, 135],
#          [142, 143, 141]],
#
#         [[175, 173, 173],
#          [176, 174, 174],
#          [178, 176, 176],
#          ...,
#          [125, 126, 124],
#          [134, 135, 133],
#          [142, 143, 141]]], dtype=uint8)
#  orig_shape: (1600, 1204)
#  path: 'c:\\Users\\johnl\\Documents\\GitHub\\avoChecker\\Pictures\\1023A\\1023A_2.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 2.0029000006616116, 'inference': 9.81860002502799, 'postprocess': 1.3460000045597553},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hass', 1: 'Shepard'}
#  obb: None
#  orig_img: array([[[  2,   2,   2],
#          [  2,   2,   2],
#          [  2,   2,   2],
#          ...,
#          [118, 132, 144],
#          [119, 133, 145],
#          [120, 134, 146]],
#
#         [[  2,   2,   2],
#          [  2,   2,   2],
#          [  2,   2,   2],
#          ...,
#          [118, 132, 144],
#          [119, 133, 145],
#          [120, 134, 146]],
#
#         [[  2,   2,   2],
#          [  2,   2,   2],
#          [  2,   2,   2],
#          ...,
#          [117, 131, 143],
#          [118, 132, 144],
#          [119, 133, 145]],
#
#         ...,
#
#         [[160, 180, 235],
#          [160, 180, 235],
#          [160, 180, 235],
#          ...,
#          [135, 131, 136],
#          [142, 138, 143],
#          [146, 142, 147]],
#
#         [[160, 180, 235],
#          [160, 180, 235],
#          [160, 180, 235],
#          ...,
#          [143, 139, 144],
#          [149, 145, 150],
#          [152, 148, 153]],
#
#         [[160, 180, 235],
#          [160, 180, 235],
#          [160, 180, 235],
#          ...,
#          [158, 154, 159],
#          [165, 161, 166],
#          [169, 165, 170]]], dtype=uint8)
#  orig_shape: (1600, 1204)
#  path: 'c:\\Users\\johnl\\Documents\\GitHub\\avoChecker\\Pictures\\1023A\\1023A_3.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 1.965200062841177, 'inference': 9.739200118929148, 'postprocess': 1.2997000012546778},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hass', 1: 'Shepard'}
#  obb: None
#  orig_img: array([[[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [127, 140, 148],
#          [127, 140, 148],
#          [127, 140, 148]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [127, 140, 148],
#          [127, 140, 148],
#          [127, 140, 148]],
#
#         [[  1,   1,   1],
#          [  1,   1,   1],
#          [  1,   1,   1],
#          ...,
#          [128, 141, 149],
#          [128, 141, 149],
#          [128, 141, 149]],
#
#         ...,
#
#         [[151, 175, 229],
#          [151, 175, 229],
#          [151, 175, 229],
#          ...,
#          [178, 179, 175],
#          [183, 184, 180],
#          [189, 190, 186]],
#
#         [[151, 175, 229],
#          [151, 175, 229],
#          [151, 175, 229],
#          ...,
#          [169, 171, 165],
#          [162, 164, 158],
#          [157, 159, 153]],
#
#         [[151, 175, 229],
#          [151, 175, 229],
#          [151, 175, 229],
#          ...,
#          [169, 171, 165],
#          [152, 154, 148],
#          [140, 142, 136]]], dtype=uint8)
#  orig_shape: (1600, 1204)
#  path: 'c:\\Users\\johnl\\Documents\\GitHub\\avoChecker\\Pictures\\1023A\\1023A_4.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 2.017199993133545, 'inference': 9.716300060972571, 'postprocess': 1.4292001724243164},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hass', 1: 'Shepard'}
#  obb: None
#  orig_img: array([[[ 11,  10,  12],
#          [ 11,  10,  12],
#          [ 11,  10,  12],
#          ...,
#          [108, 123, 132],
#          [108, 123, 132],
#          [108, 123, 132]],
#
#         [[ 11,  10,  12],
#          [ 11,  10,  12],
#          [ 11,  10,  12],
#          ...,
#          [108, 123, 132],
#          [108, 123, 132],
#          [108, 123, 132]],
#
#         [[ 11,  10,  12],
#          [ 11,  10,  12],
#          [ 11,  10,  12],
#          ...,
#          [108, 123, 132],
#          [108, 123, 132],
#          [108, 123, 132]],
#
#         ...,
#
#         [[162, 178, 237],
#          [162, 178, 237],
#          [162, 178, 237],
#          ...,
#          [147, 151, 146],
#          [147, 151, 146],
#          [146, 150, 145]],
#
#         [[161, 177, 236],
#          [161, 177, 236],
#          [161, 177, 236],
#          ...,
#          [147, 151, 146],
#          [145, 149, 144],
#          [144, 148, 143]],
#
#         [[161, 177, 236],
#          [161, 177, 236],
#          [161, 177, 236],
#          ...,
#          [146, 150, 145],
#          [144, 148, 143],
#          [142, 146, 141]]], dtype=uint8)
#  orig_shape: (1600, 1204)
#  path: 'c:\\Users\\johnl\\Documents\\GitHub\\avoChecker\\Pictures\\1023A\\1023A_5.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 2.2315001115202904, 'inference': 9.527599904686213, 'postprocess': 1.3945000246167183},
#  ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'Hass', 1: 'Shepard'}
#  obb: None
#  orig_img: array([[[  5,   5,   5],
#          [  5,   5,   5],
#          [  5,   5,   5],
#          ...,
#          [163, 166, 174],
#          [163, 166, 174],
#          [163, 166, 174]],
#
#         [[  5,   5,   5],
#          [  5,   5,   5],
#          [  5,   5,   5],
#          ...,
#          [163, 166, 174],
#          [163, 166, 174],
#          [163, 166, 174]],
#
#         [[  5,   5,   5],
#          [  5,   5,   5],
#          [  5,   5,   5],
#          ...,
#          [161, 167, 174],
#          [161, 167, 174],
#          [161, 167, 174]],
#
#         ...,
#
#         [[157, 168, 226],
#          [157, 168, 226],
#          [157, 168, 226],
#          ...,
#          [169, 168, 164],
#          [158, 157, 153],
#          [147, 146, 142]],
#
#         [[157, 168, 226],
#          [157, 168, 226],
#          [157, 168, 226],
#          ...,
#          [175, 174, 170],
#          [164, 163, 159],
#          [153, 152, 148]],
#
#         [[157, 168, 226],
#          [157, 168, 226],
#          [157, 168, 226],
#          ...,
#          [180, 179, 175],
#          [170, 169, 165],
#          [161, 160, 156]]], dtype=uint8)
#  orig_shape: (1600, 1204)
#  path: 'c:\\Users\\johnl\\Documents\\GitHub\\avoChecker\\Pictures\\1023A\\1023A_6.jpg'
#  probs: None
#  save_dir: 'runs\\detect\\predict'
#  speed: {'preprocess': 1.906299963593483, 'inference': 10.29270002618432, 'postprocess': 1.4633999671787024}]
